# %% [raw]
# 1. What is a random variable in probability theory?
#     Ans. Random Variable: A function that assigns numerical values to outcomes in a sample space of a random experiment.

# %% [raw]
# 2. What are the types of random variables?
#     Ans. Types of Random Variables:
#             Discrete: Takes countable values (e.g., number of heads in coin tosses).
#             Continuous: Takes an infinite number of values in an interval (e.g., height, temperature).

# %% [raw]
# 3. What is the difference between discrete and continuous distributions?
#     Ans. Difference between Discrete and Continuous Distributions:
#             Discrete: Defined at specific points (probabilities sum to 1).
#             Continuous: Defined over intervals using probability density functions (area under the curve = 1).

# %% [raw]
# 4. What are probability distribution functions (PDF)?
#     Ans.Probability Distribution Function (PDF):
#             For discrete variables: Gives the probability of each outcome.
#             For continuous variables: Defines a density function, and probabilities are calculated over intervals.

# %% [raw]
# 5. How do cumulative distribution functions (CDF) differ from probability distribution functions (PDF)?
#     Ans. Cumulative Distribution Function (CDF):
#             Represents the probability that a random variable is ≤ a given value.
#             Unlike the PDF, the CDF always increases from 0 to 1.

# %% [raw]
# 6. What is a discrete uniform distribution?
#     Ans. Discrete Uniform Distribution:
#             A distribution where all outcomes have equal probability (e.g., rolling a fair die).

# %% [raw]
# 7. What are the key properties of a Bernoulli distribution?
#     Ans. Key Properties of Bernoulli Distribution:
#             Only two outcomes (success/failure).
#             Probability of success = p, failure = 1−𝑝
#             Mean = p, Variance = 𝑝(1−𝑝)

# %% [raw]
# 8. What is the binomial distribution, and how is it used in probability?
#     Ans. Binomial Distribution:
#             Models the number of successes in 𝑛 independent Bernoulli trials.
#             Probability mass function:

# %% [markdown]
# ![Screenshot 2025-04-04 124728.png](attachment:07300c34-fab8-4c53-a280-1158c2694e11.png)

# %% [raw]
#             Used in coin flips, quality control, etc.

# %% [raw]
# 9. What is the Poisson distribution and where is it applied?
#     Ans. Poisson Distribution:
#             Models the number of events occurring in a fixed interval (given a constant average rate).
#             Used in call centers, traffic flow, etc.

# %% [raw]
# 10. 10. What is a continuous uniform distribution?
#     Ans. Continuous Uniform Distribution:
#         All values in an interval have equal probability density.

# %% [markdown]
# ![Screenshot 2025-04-04 125356.png](attachment:c13bf302-3320-43e8-98ce-29582e3443a3.png)

# %% [raw]
# 11. What are the characteristics of a normal distribution?
#     Ans. Characteristics of Normal Distribution:
#             Symmetric, bell-shaped curve.
#             Defined by mean μ and standard deviation σ.
#             68-95-99.7 rule for standard deviations.

# %% [raw]
# 12. What is the standard normal distribution, and why is it important?
#     Ans. Standard Normal Distribution:
#             A normal distribution with mean = 0, variance = 1.
#             Used for standardizing values using Z-scores.

# %% [raw]
# 13. What is the Central Limit Theorem (CLT), and why is it critical in statistics?
#     Ans. States that the distribution of the sample mean approaches a normal distribution as the sample size increases, regardless of the population's distribution.

# %% [raw]
# 14. How does the Central Limit Theorem relate to the normal distribution?
#     Ans. CLT and Normal Distribution:
#             Justifies using normal approximations for large sample sizes.
#             Essential for inferential statistics.

# %% [raw]
# 15. What is the application of Z statistics in hypothesis testing?
#     Ans. Z-Statistics in Hypothesis Testing:
#             Used when population variance is known.
#             Compares sample means to a population mean.

# %% [raw]
# 16. How do you calculate a Z-score, and what does it represent?
#     Ans. Z-Score Calculation:

# %% [markdown]
# ![Screenshot 2025-04-04 125844.png](attachment:16ab5457-b239-4ac7-a2e7-fd7d5136ec2a.png)

# %%
            Measures how far a value is from the mean in standard deviations.

# %% [raw]
# 17. What are point estimates and interval estimates in statistics?
# Point vs. Interval Estimates:
#     Point estimate: Single best guess for a parameter (e.g., sample mean).
#     Interval estimate: Range within which the parameter likely falls (e.g., confidence intervals).

# %% [raw]
# 18. What is the significance of confidence intervals in statistical analysis?
#     Ans. Confidence Intervals:
#             Express the range of values likely containing the true population parameter with a given confidence level (e.g., 95%).

# %% [raw]
# 19. What is the relationship between a Z-score and a confidence interval?
#     Ans. Z-Score & Confidence Interval Relationship:
#             A Z-score helps determine the margin of error for a confidence interval.

# %% [raw]
# 20. How are Z-scores used to compare different distributions?
#     Ans. Using Z-Scores to Compare Distributions:
#             Standardizes different distributions for direct comparison.

# %% [raw]
# 21. What are the assumptions for applying the Central Limit Theorem?
#     Ans. Assumptions for CLT:
#             Independent and identically distributed (iid) samples.
#             Sample size is large (usually 𝑛≥30).

# %% [raw]
# 22. What is the concept of expected value in a probability distribution?
#     Ans. Expected Value (EV):
#             Long-run average outcome of a probability distribution:

# %% [markdown]
# ![Screenshot 2025-04-04 130352.png](attachment:4435175a-b4f0-45d5-9d2f-3378196298ed.png)

# %% [raw]
# 23. How does a probability distribution relate to the expected outcome of a random variable?
#     Ans. Probability Distribution & Expected Outcome:
#             The expected value represents the mean of the distribution, giving insight into the average result over repeated trials.

# %% [markdown]
# <<<< Practical >>>>

# %%
# 1. Write a Python program to generate a random variable and display its value?

import random

# Generate a random integer between 1 and 100
random_variable = random.randint(1, 100)

# Display the generated random value
print("Generated Random Value:", random_variable)
# Out:
# Generated Random Value: 56

# %%
#2. Generate a discrete uniform distribution using Python and plot the probability mass function (PMF).

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range of the discrete uniform distribution
low, high = 1, 10  # Generates integers from 1 to 9

# Generate values
x = np.arange(low, high)
pmf_values = randint.pmf(x, low, high)

# Plot the PMF
plt.bar(x, pmf_values, color='blue', alpha=0.6, edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Probability')
plt.title('PMF of Discrete Uniform Distribution')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# 3.Write a Python function to calculate the probability distribution function (PDF) of a Bernoulli distribution. 

def bernoulli_pmf(x, p):
    """
    Computes the probability mass function (PMF) of a Bernoulli distribution.

    Parameters:
    x (int): The value of the random variable (0 or 1).
    p (float): The probability of success (0 ≤ p ≤ 1).

    Returns:
    float: Probability P(X = x).
    """
    if x not in [0, 1]:
        raise ValueError("x must be 0 or 1 for a Bernoulli distribution.")
    if not (0 <= p <= 1):
        raise ValueError("p must be between 0 and 1.")

    return p**x * (1 - p)**(1 - x)

# Example usage:
p = 0.6  # Probability of success
print("P(X=0):", bernoulli_pmf(0, p))
print("P(X=1):", bernoulli_pmf(1, p))
# Out:
# P(X=0): 0.4
# P(X=1): 0.6

# %%
# 4. Write a Python script to simulate a binomial distribution with n=10 and p=0.5, then plot its histogram.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Parameters for the binomial distribution
n = 10   # Number of trials
p = 0.5  # Probability of success

# Simulate 1000 random samples from the binomial distribution
samples = np.random.binomial(n, p, 1000)

# Plot the histogram
plt.hist(samples, bins=np.arange(n+2)-0.5, density=True, alpha=0.6, color='blue', edgecolor='black')

# Overlay the theoretical PMF
x = np.arange(0, n+1)
pmf_values = binom.pmf(x, n, p)
plt.plot(x, pmf_values, 'ro-', label='PMF')

# Labels and title
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution Histogram (n={n}, p={p})')
plt.xticks(range(n+1))
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 5. Create a Poisson distribution and visualize it using Python.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

# Define the Poisson distribution parameter (mean number of events)
lambda_ = 5  # Average number of occurrences

# Generate values for the Poisson PMF
x = np.arange(0, 15)  # Possible values from 0 to 14
pmf_values = poisson.pmf(x, lambda_)

# Plot the PMF
plt.bar(x, pmf_values, color='blue', alpha=0.6, edgecolor='black')

# Labels and title
plt.xlabel('Number of Events')
plt.ylabel('Probability')
plt.title(f'Poisson Distribution (λ={lambda_})')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# 6. Write a Python program to calculate and plot the cumulative distribution function (CDF) of a discrete uniform distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint

# Define the range of the discrete uniform distribution
low, high = 1, 10  # Generates integers from 1 to 9

# Generate values
x = np.arange(low, high)
cdf_values = randint.cdf(x, low, high)

# Plot the CDF
plt.step(x, cdf_values, where='mid', color='blue', label='CDF')
plt.scatter(x, cdf_values, color='red', zorder=3)  # Mark points on CDF

# Labels and title
plt.xlabel('Values')
plt.ylabel('Cumulative Probability')
plt.title('CDF of Discrete Uniform Distribution')
plt.xticks(x)
plt.yticks(np.linspace(0, 1, high-low))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

# Show the plot
plt.show()

# %%
# 7. Generate a continuous uniform distribution using NumPy and visualize it.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

# Define parameters for the uniform distribution
a, b = 0, 10  # Range: [a, b]

# Generate random samples
samples = np.random.uniform(a, b, 1000)

# Plot histogram
plt.hist(samples, bins=30, density=True, alpha=0.6, color='blue', edgecolor='black', label='Histogram')

# Generate theoretical PDF
x = np.linspace(a, b, 100)
pdf_values = uniform.pdf(x, a, b-a)
plt.plot(x, pdf_values, 'r-', label='PDF')

# Labels and title
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Continuous Uniform Distribution')
plt.legend()
plt.grid(alpha=0.7)

# Show the plot
plt.show()

# %%
# 8. Simulate data from a normal distribution and plot its histogram.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define parameters for the normal distribution
mu, sigma = 0, 1  # Mean and standard deviation

# Generate random samples from the normal distribution
samples = np.random.normal(mu, sigma, 1000)

# Plot histogram
plt.hist(samples, bins=30, density=True, alpha=0.6, color='blue', edgecolor='black', label='Histogram')

# Generate theoretical PDF
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 100)
pdf_values = norm.pdf(x, mu, sigma)
plt.plot(x, pdf_values, 'r-', label='PDF')

# Labels and title
plt.xlabel('Values')
plt.ylabel('Probability Density')
plt.title('Histogram of Normal Distribution')
plt.legend()
plt.grid(alpha=0.7)

# Show the plot
plt.show()

# %%
#9.  Write a Python function to calculate Z-scores from a dataset and plot them.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def compute_and_plot_z_scores(data):
    """
    Computes Z-scores for a dataset and plots a histogram of the Z-scores.

    Parameters:
    data (array-like): Input dataset.
    """
    # Compute mean and standard deviation
    mean = np.mean(data)
    std_dev = np.std(data, ddof=1)  # Using ddof=1 for sample standard deviation

    # Compute Z-scores
    z_scores = (data - mean) / std_dev

    # Plot histogram of Z-scores
    plt.figure(figsize=(8, 5))
    sns.histplot(z_scores, bins=30, kde=True, color='blue', edgecolor='black')

    # Add labels and title
    plt.xlabel('Z-score')
    plt.ylabel('Frequency')
    plt.title('Histogram of Z-scores')
    plt.axvline(0, color='red', linestyle='--', label='Mean (Z=0)')
    plt.legend()
    plt.grid(alpha=0.5)

    # Show plot
    plt.show()

    return z_scores

# Example usage with random normal data
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=1000)  # Normal distribution (mean=50, std=10)
z_scores = compute_and_plot_z_scores(sample_data)

# %%
# 10. Implement the Central Limit Theorem (CLT) using Python for a non-normal distribution.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Generate a non-normal (exponential) distribution
np.random.seed(42)
population = np.random.exponential(scale=2, size=10000)  # Exponential distribution

# Step 2: Function to perform CLT simulation
def central_limit_theorem(population, sample_size, num_samples=1000):
    sample_means = []  # Store sample means

    # Step 3: Draw samples and compute means
    for _ in range(num_samples):
        sample = np.random.choice(population, size=sample_size, replace=True)
        sample_means.append(np.mean(sample))

    # Step 4: Plot histogram of sample means
    plt.figure(figsize=(8, 5))
    sns.histplot(sample_means, bins=30, kde=True, color='blue', edgecolor='black')

    # Add mean and normal curve
    plt.axvline(np.mean(sample_means), color='red', linestyle='--', label=f'Mean={np.mean(sample_means):.2f}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')
    plt.title(f'CLT Demonstration (Sample Size = {sample_size})')
    plt.legend()
    plt.grid(alpha=0.5)
    
    # Show plot
    plt.show()

# Step 5: Test CLT with different sample sizes
for size in [5, 30, 100]:  # Small, medium, large sample sizes
    central_limit_theorem(population, sample_size=size)

# %%
# 15. Simulate multiple samples from a normal distribution and verify the Central Limit Theorem.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# Step 1: Generate a normal population
np.random.seed(42)  # For reproducibility
mu, sigma = 50, 10  # Mean and standard deviation
population = np.random.normal(mu, sigma, 10000)  # Large normal population

# Step 2: Function to perform CLT simulation
def central_limit_theorem_normal(population, sample_size, num_samples=1000):
    sample_means = []  # Store sample means

    # Step 3: Draw samples and compute means
    for _ in range(num_samples):
        sample = np.random.choice(population, size=sample_size, replace=True)
        sample_means.append(np.mean(sample))

    # Step 4: Plot histogram of sample means
    plt.figure(figsize=(8, 5))
    sns.histplot(sample_means, bins=30, kde=True, color='blue', edgecolor='black')

    # Overlay normal curve
    mean_of_means = np.mean(sample_means)
    std_of_means = np.std(sample_means, ddof=1)
    x = np.linspace(mean_of_means - 4*std_of_means, mean_of_means + 4*std_of_means, 100)
    plt.plot(x, norm.pdf(x, mean_of_means, std_of_means), 'r-', label='Normal Curve')

    # Labels and title
    plt.axvline(mean_of_means, color='red', linestyle='--', label=f'Mean={mean_of_means:.2f}')
    plt.xlabel('Sample Mean')
    plt.ylabel('Frequency')
    plt.title(f'CLT Verification (Sample Size = {sample_size})')
    plt.legend()
    plt.grid(alpha=0.5)
    
    # Show plot
    plt.show()

# Step 5: Test CLT with different sample sizes
for size in [5, 30, 100]:  # Small, medium, large sample sizes
    central_limit_theorem_normal(population, sample_size=size)

# %%
# 16. Write a Python function to calculate and plot the standard normal distribution (mean = 0, std = 1).

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_standard_normal_distribution():
    """
    Plots the probability density function (PDF) of the standard normal distribution (N(0,1)).
    """
    # Generate values for x-axis
    x = np.linspace(-4, 4, 1000)  # Standard normal range

    # Compute the PDF of standard normal distribution
    pdf_values = norm.pdf(x, loc=0, scale=1)

    # Plot the standard normal distribution
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf_values, color='blue', label='Standard Normal PDF')
    
    # Add mean and standard deviation lines
    plt.axvline(0, color='red', linestyle='--', label='Mean (0)')
    plt.axvline(1, color='green', linestyle='--', alpha=0.6, label='1 Std Dev')
    plt.axvline(-1, color='green', linestyle='--', alpha=0.6)
    
    # Labels and title
    plt.xlabel('X')
    plt.ylabel('Probability Density')
    plt.title('Standard Normal Distribution (N(0,1))')
    plt.legend()
    plt.grid(alpha=0.5)

    # Show the plot
    plt.show()

# Call the function
plot_standard_normal_distribution()

# %%
#17. Generate random variables and calculate their corresponding probabilities using the binomial distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# Define parameters for the binomial distribution
n, p = 10, 0.5  # 10 trials, 50% success probability

# Generate random variables from binomial distribution
random_variables = np.random.binomial(n, p, 1000)  # 1000 samples

# Calculate the probabilities (PMF) for possible values of X
x_values = np.arange(0, n + 1)  # Possible values of X (0 to n)
probabilities = binom.pmf(x_values, n, p)  # PMF calculation

# Plot histogram of random variables
plt.figure(figsize=(8, 5))
plt.hist(random_variables, bins=np.arange(n+2)-0.5, density=True, alpha=0.6, color='blue', edgecolor='black', label='Simulated Data')

# Plot PMF
plt.plot(x_values, probabilities, 'ro-', label='Theoretical PMF')

# Labels and title
plt.xlabel('Number of Successes (k)')
plt.ylabel('Probability')
plt.title(f'Binomial Distribution (n={n}, p={p})')
plt.xticks(x_values)
plt.legend()
plt.grid(alpha=0.5)

# Show the plot
plt.show()

# %%
# 18. Write a Python program to calculate the Z-score for a given data point and compare it to a standard normal distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def calculate_z_score(data_point, dataset):
    """
    Calculates the Z-score for a given data point within a dataset and visualizes it.
    
    Parameters:
    data_point (float): The value for which the Z-score is calculated.
    dataset (list or np.array): The dataset from which the mean and standard deviation are computed.

    Returns:
    float: The calculated Z-score.
    """
    # Compute mean and standard deviation
    mean = np.mean(dataset)
    std_dev = np.std(dataset, ddof=1)  # Sample standard deviation

    # Compute Z-score
    z_score = (data_point - mean) / std_dev
    print(f"Z-score for X={data_point}: {z_score:.2f}")

    # Generate standard normal distribution for comparison
    x = np.linspace(-4, 4, 1000)  # Standard normal range
    pdf_values = norm.pdf(x, loc=0, scale=1)  # Standard normal PDF

    # Plot standard normal distribution
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf_values, label="Standard Normal Distribution (N(0,1))", color='blue')

    # Mark the Z-score on the curve
    plt.axvline(z_score, color='red', linestyle='--', label=f'Z-score={z_score:.2f}')

    # Labels and title
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.title('Comparison of Z-score with Standard Normal Distribution')
    plt.legend()
    plt.grid(alpha=0.5)

    # Show the plot
    plt.show()

    return z_score

# Example usage
np.random.seed(42)
sample_dataset = np.random.normal(loc=50, scale=10, size=1000)  # Generate a normal dataset
calculate_z_score(60, sample_dataset)  # Calculate Z-score for X=60
# Out:
# Z-score for X=60: 1.00
# 1.0014828251271093

# %%
# 19. Implement hypothesis testing using Z-statistics for a sample dataset.

import numpy as np
import scipy.stats as stats

def z_test(sample, population_mean, population_std, alpha=0.05):
    """
    Performs a one-sample Z-test for a given sample against a population mean.
    
    Parameters:
    sample (list or np.array): The sample dataset.
    population_mean (float): The known population mean.
    population_std (float): The known population standard deviation.
    alpha (float): The significance level (default: 0.05).

    Returns:
    None (prints hypothesis test results).
    """
    # Sample statistics
    sample_mean = np.mean(sample)
    sample_size = len(sample)
    
    # Compute Z-score
    z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
    
    # Compute P-value (two-tailed test)
    p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

    # Print results
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Z-score: {z_score:.2f}")
    print(f"P-value: {p_value:.5f}")

    # Decision rule
    if p_value < alpha:
        print("Conclusion: Reject the null hypothesis (H0) - Significant difference found.")
    else:
        print("Conclusion: Fail to reject the null hypothesis (H0) - No significant difference.")

# Example usage
np.random.seed(42)
sample_data = np.random.normal(loc=52, scale=10, size=30)  # Simulated sample
z_test(sample_data, population_mean=50, population_std=10)
# Out:
# Sample Mean: 50.12
# Z-score: 0.06
# P-value: 0.94824
# Conclusion: Fail to reject the null hypothesis (H0) - No significant difference.

# %%
# 20. Create a confidence interval for a dataset using Python and interpret the result.

import numpy as np
import scipy.stats as stats

def confidence_interval(sample, confidence=0.95):
    """
    Calculates the confidence interval for a given sample dataset.

    Parameters:
    sample (list or np.array): The sample dataset.
    confidence (float): The confidence level (default: 0.95 for 95% CI).

    Returns:
    tuple: (lower_bound, upper_bound) of the confidence interval.
    """
    # Sample statistics
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation (unbiased)
    n = len(sample)

    # Critical Z-value (for large samples) or t-value (if sample size is small)
    z_critical = stats.norm.ppf(1 - (1 - confidence) / 2)  # For normal distribution

    # Compute margin of error
    margin_of_error = z_critical * (sample_std / np.sqrt(n))

    # Confidence interval bounds
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    # Print results
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Margin of Error: {margin_of_error:.2f}")
    print(f"{confidence * 100:.0f}% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

    return lower_bound, upper_bound

# Example usage
np.random.seed(42)
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Simulated sample dataset
confidence_interval(sample_data)
# Out:
# Sample Mean: 48.12
# Margin of Error: 3.22
# 95% Confidence Interval: (44.90, 51.34)
# (44.89795858305723, 51.33910349992202)

# %%
# 21. Generate data from a normal distribution, then calculate and interpret the confidence interval for its mean.

import numpy as np
import scipy.stats as stats

def calculate_confidence_interval(sample, confidence=0.95):
    """
    Calculates the confidence interval for a given sample dataset using the t-distribution.
    
    Parameters:
    sample (list or np.array): The sample dataset.
    confidence (float): The confidence level (default: 0.95 for 95% CI).
    
    Returns:
    tuple: (lower_bound, upper_bound) of the confidence interval.
    """
    # Sample statistics
    sample_mean = np.mean(sample)
    sample_std = np.std(sample, ddof=1)  # Sample standard deviation (unbiased)
    n = len(sample)

    # Critical t-value (used for small samples or unknown population std)
    t_critical = stats.t.ppf(1 - (1 - confidence) / 2, df=n - 1)  # Two-tailed test

    # Compute margin of error
    margin_of_error = t_critical * (sample_std / np.sqrt(n))

    # Confidence interval bounds
    lower_bound = sample_mean - margin_of_error
    upper_bound = sample_mean + margin_of_error

    # Print results
    print(f"Sample Mean: {sample_mean:.2f}")
    print(f"Margin of Error: {margin_of_error:.2f}")
    print(f"{confidence * 100:.0f}% Confidence Interval: ({lower_bound:.2f}, {upper_bound:.2f})")

    return lower_bound, upper_bound

# Step 1: Generate Data from a Normal Distribution
np.random.seed(42)  # For reproducibility
sample_data = np.random.normal(loc=50, scale=10, size=30)  # Normal(mean=50, std=10, size=30)

# Step 2: Compute and Interpret Confidence Interval
calculate_confidence_interval(sample_data)
# Out:
# Sample Mean: 48.12
# Margin of Error: 3.36
# 95% Confidence Interval: (44.76, 51.48)
# (44.75785181035169, 51.47921027262756)

# %%
# 22. Write a Python script to calculate and visualize the probability density function (PDF) of a normal distribution.
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

def plot_normal_pdf(mean=0, std_dev=1, num_points=1000):
    """
    Plots the Probability Density Function (PDF) of a normal distribution.

    Parameters:
    mean (float): The mean (μ) of the normal distribution.
    std_dev (float): The standard deviation (σ) of the normal distribution.
    num_points (int): Number of points to generate for plotting.

    Returns:
    None (Displays the plot).
    """
    # Generate x values
    x = np.linspace(mean - 4*std_dev, mean + 4*std_dev, num_points)

    # Compute PDF values
    pdf_values = norm.pdf(x, loc=mean, scale=std_dev)

    # Plot the normal distribution
    plt.figure(figsize=(8, 5))
    plt.plot(x, pdf_values, color='blue', label=f'Normal PDF (μ={mean}, σ={std_dev})')

    # Add mean and standard deviation lines
    plt.axvline(mean, color='red', linestyle='--', label='Mean (μ)')
    plt.axvline(mean - std_dev, color='green', linestyle='--', alpha=0.6, label='1 Std Dev (σ)')
    plt.axvline(mean + std_dev, color='green', linestyle='--', alpha=0.6)

    # Labels and title
    plt.xlabel('X')
    plt.ylabel('Probability Density')
    plt.title('Normal Distribution PDF')
    plt.legend()
    plt.grid(alpha=0.5)

    # Show the plot
    plt.show()

# Example usage
plot_normal_pdf(mean=50, std_dev=10)

# %%
# 23. Use Python to calculate and interpret the cumulative distribution function (CDF) of a Poisson distribution.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson

def poisson_cdf(lambda_value, max_k=20):
    """
    Calculates and visualizes the cumulative distribution function (CDF) of a Poisson distribution.

    Parameters:
    lambda_value (float): The mean (λ) of the Poisson distribution.
    max_k (int): The maximum number of occurrences to calculate CDF for.

    Returns:
    None (Displays the plot).
    """
    # Generate possible values of k
    k_values = np.arange(0, max_k + 1)

    # Compute CDF values
    cdf_values = poisson.cdf(k_values, mu=lambda_value)

    # Plot the Poisson CDF
    plt.figure(figsize=(8, 5))
    plt.step(k_values, cdf_values, where='mid', color='blue', label=f'Poisson CDF (λ={lambda_value})')

    # Highlight key points
    plt.scatter(k_values, cdf_values, color='red', marker='o')

    # Labels and title
    plt.xlabel('Number of Events (k)')
    plt.ylabel('Cumulative Probability (P(X ≤ k))')
    plt.title('Poisson Distribution CDF')
    plt.legend()
    plt.grid(alpha=0.5)

    # Show the plot
    plt.show()

    # Print some key probabilities
    print(f"Probability that X ≤ 5: {poisson.cdf(5, mu=lambda_value):.4f}")
    print(f"Probability that X ≤ 10: {poisson.cdf(10, mu=lambda_value):.4f}")
    print(f"Probability that X ≤ 15: {poisson.cdf(15, mu=lambda_value):.4f}")

# Example usage
poisson_cdf(lambda_value=7, max_k=20)
# Out:
# Probability that X ≤ 5: 0.3007
# Probability that X ≤ 10: 0.9015
# Probability that X ≤ 15: 0.9976

# %%
# 24. Simulate a random variable using a continuous uniform distribution and calculate its expected value.

import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform

def simulate_uniform_distribution(a=0, b=10, num_samples=1000):
    """
    Simulates a continuous uniform distribution, plots the histogram, and calculates the expected value.

    Parameters:
    a (float): Lower bound of the uniform distribution.
    b (float): Upper bound of the uniform distribution.
    num_samples (int): Number of random samples to generate.

    Returns:
    None (Displays the plot and prints the expected value).
    """
    # Generate random samples
    samples = np.random.uniform(a, b, num_samples)

    # Compute the expected value (theoretical and empirical)
    expected_value_theoretical = (a + b) / 2
    expected_value_empirical = np.mean(samples)

    # Plot histogram
    plt.figure(figsize=(8, 5))
    plt.hist(samples, bins=30, density=True, alpha=0.6, color='blue', label='Sampled Data')

    # Plot the uniform PDF for reference
    x = np.linspace(a, b, 100)
    pdf_values = uniform.pdf(x, loc=a, scale=(b-a))
    plt.plot(x, pdf_values, color='red', label='Uniform PDF')

    # Labels and title
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.title(f'Continuous Uniform Distribution U({a}, {b})')
    plt.legend()
    plt.grid(alpha=0.5)

    # Show the plot
    plt.show()

    # Print expected values
    print(f"Theoretical Expected Value: {expected_value_theoretical:.2f}")
    print(f"Empirical Expected Value (from samples): {expected_value_empirical:.2f}")

# Example usage
simulate_uniform_distribution(a=2, b=12, num_samples=1000)
# Out:
# Theoretical Expected Value: 7.00
# Empirical Expected Value (from samples): 6.95

# %%
# 25. Write a Python program to compare the standard deviations of two datasets and visualize the difference.

import numpy as np
import matplotlib.pyplot as plt

def compare_standard_deviations(dataset1, dataset2, label1="Dataset 1", label2="Dataset 2"):
    """
    Compares the standard deviations of two datasets and visualizes the difference.

    Parameters:
    dataset1 (list or np.array): First dataset.
    dataset2 (list or np.array): Second dataset.
    label1 (str): Label for first dataset.
    label2 (str): Label for second dataset.

    Returns:
    None (Displays a histogram and prints standard deviations).
    """
    # Compute standard deviations
    std_dev1 = np.std(dataset1, ddof=1)  # Sample standard deviation
    std_dev2 = np.std(dataset2, ddof=1)

    # Print standard deviations
    print(f"{label1} - Standard Deviation: {std_dev1:.2f}")
    print(f"{label2} - Standard Deviation: {std_dev2:.2f}")

    # Plot histograms
    plt.figure(figsize=(8, 5))
    plt.hist(dataset1, bins=20, alpha=0.6, color='blue', label=f"{label1} (σ={std_dev1:.2f})", edgecolor='black')
    plt.hist(dataset2, bins=20, alpha=0.6, color='red', label=f"{label2} (σ={std_dev2:.2f})", edgecolor='black')

    # Labels and title
    plt.xlabel('Value')
    plt.ylabel('Frequency')
    plt.title('Comparison of Standard Deviations')
    plt.legend()
    plt.grid(alpha=0.5)

    # Show the plot
    plt.show()

# Example usage
np.random.seed(42)
dataset1 = np.random.normal(loc=50, scale=10, size=1000)  # Normal(mean=50, std=10)
dataset2 = np.random.normal(loc=50, scale=20, size=1000)  # Normal(mean=50, std=20)

compare_standard_deviations(dataset1, dataset2, label1="Dataset 1 (σ=10)", label2="Dataset 2 (σ=20)")
# Out:
# Dataset 1 (σ=10) - Standard Deviation: 9.79
# Dataset 2 (σ=20) - Standard Deviation: 19.95

# %%
# 26. Calculate the range and interquartile range (IQR) of a dataset generated from a normal distribution.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_range_and_iqr(data):
    """
    Calculates and prints the range and interquartile range (IQR) of a dataset.
    
    Parameters:
    data (list or np.array): The dataset.

    Returns:
    None (Prints the range and IQR, and displays a boxplot).
    """
    # Calculate range
    data_range = np.max(data) - np.min(data)

    # Calculate quartiles
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    
    # Compute IQR
    IQR = Q3 - Q1

    # Print results
    print(f"Range: {data_range:.2f}")
    print(f"Interquartile Range (IQR): {IQR:.2f}")

    # Plot boxplot
    plt.figure(figsize=(6, 4))
    sns.boxplot(data, color='lightblue')
    plt.title("Boxplot of Dataset (Showing IQR)")
    plt.xlabel("Values")
    plt.grid(alpha=0.5)
    plt.show()

# Generate a normal distribution dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=500)  # Normal(mean=50, std=15, size=500)

# Compute and display range and IQR
calculate_range_and_iqr(data)
# Out:
# Range: 106.41
# Interquartile Range (IQR): 20.06

# %%
# 27. Implement Z-score normalization on a dataset and visualize its transformation.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_skewness_kurtosis(data):
    """
    Calculates and prints the skewness and kurtosis of a dataset.
    Also visualizes the dataset using a histogram.

    Parameters:
    data (list or np.array): The dataset.

    Returns:
    None (Prints skewness and kurtosis and displays a histogram).
    """
    # Compute skewness and kurtosis
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data, fisher=True)  # Fisher=True returns excess kurtosis (normal = 0)

    # Print results
    print(f"Skewness: {skewness:.4f}")
    print(f"Excess Kurtosis: {kurtosis:.4f}")  # If close to 0, it's a normal distribution

    # Plot histogram
    plt.figure(figsize=(8, 5))
    sns.histplot(data, bins=30, kde=True, color='blue')
    plt.axvline(np.mean(data), color='red', linestyle='dashed', linewidth=2, label="Mean")
    plt.title("Histogram of Dataset (Checking Normality)")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(alpha=0.5)
    plt.show()

# Generate a normal distribution dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)  # Normal(mean=50, std=15, size=1000)

# Compute and display skewness & kurtosis
calculate_skewness_kurtosis(data)
# Out:
# Skewness: 0.1168
# Excess Kurtosis: 0.0662

# %%
# 28. Write a Python function to calculate the skewness and kurtosis of a dataset generated from a normal distribution.

import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_skewness_kurtosis(data):
    """
    Calculates and prints the skewness and kurtosis of a dataset.
    Also visualizes the dataset using a histogram.

    Parameters:
    data (list or np.array): The dataset.

    Returns:
    None (Prints skewness and kurtosis and displays a histogram).
    """
    # Compute skewness and kurtosis
    skewness = stats.skew(data)
    kurtosis = stats.kurtosis(data, fisher=True)  # Excess kurtosis (Normal = 0)

    # Print results
    print(f"Skewness: {skewness:.4f}")
    print(f"Excess Kurtosis: {kurtosis:.4f}")  # If close to 0, it's a normal distribution

    # Plot histogram
    plt.figure(figsize=(8, 5))
    sns.histplot(data, bins=30, kde=True, color='blue')
    plt.axvline(np.mean(data), color='red', linestyle='dashed', linewidth=2, label="Mean")
    plt.title("Histogram of Dataset (Checking Normality)")
    plt.xlabel("Value")
    plt.ylabel("Frequency")
    plt.legend()
    plt.grid(alpha=0.5)
    plt.show()

# Generate a normal distribution dataset
np.random.seed(42)
data = np.random.normal(loc=50, scale=15, size=1000)  # Normal(mean=50, std=15, size=1000)

# Compute and display skewness & kurtosis
calculate_skewness_kurtosis(data)
# Out:
# Skewness: 0.1168
# Excess Kurtosis: 0.0662
